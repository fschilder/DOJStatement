# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
prosecutors = pd.read_excel("../data/FederalProsecutors.xlsx")

# %%
prosecutors.head()
# Out:
#   First name   Last name                                  Highest DOJ title  \
# 0   David W.     Mernitz                        First Assistant US Attorney
# 1  Frederick        Hess  Director Office of Enforcement Operations, Cri...
# 2    Burtis   Dougherty                              Senior Trial Attorney
# 3       John       Kolar                               Senior Trial Counsel
# 4  E. Thomas     Roberts  Chief of Narcotics Division, District of Maryland
#
#   # years DOJ service                                Admins served under
# 0          SD Indiana                                   Johnson, Kennedy
# 1                  43  Obama, Bush II, Clinton, Bush I, Reagan, Carte...
# 2                  42  Trump, Obama, Bush II, Clinton, Bush I, Reagan...
# 3                  41  Trump;Obama;Bush II;Clinton;Bush I;Reagan;Cart...
# 4                  40  Obama, Bush II, Clinton, Bush I, Reagan, Carte...

# %%
# drop the first row (David W. Mernitz does not have a valid value for years in DOJ service)
prosecutors = prosecutors[1:]

# %%
# replace semicolons with commas for seperating admins
prosecutors["Admins served under"] = prosecutors["Admins served under"].str.replace(";",",")

# %%
prosecutors.describe()
# Out:
#        First name Last name        Highest DOJ title  # years DOJ service  \
# count         802       802                      802                802.0
# unique        397       726                      495                 62.0
# top        Robert    Martin  Assistant U.S. Attorney                  5.0
# freq           33         6                       79                 73.0
#
#        Admins served under
# count                  802
# unique                 124
# top         Reagan, Carter
# freq                    44

# %%
sns.distplot(prosecutors["# years DOJ service"], bins=20, kde=False, rug=True)

# %%
prosecutors["# years DOJ service"].mean()
# Out:
# 12.43778054862843

# %%
prosecutors["# years DOJ service"].median()
# Out:
# 8.0

# %%
adminDur = {'Trump':2.3,'Obama':8,"Bush II":8,'Clinton':8,'Bush I':4,'Reagan':8,'Carter':4,'Ford':2.34,
           'Nixon':5.6, 'Johnson':5.15, 'Kennedy':2.84, 'Eisenhower':8}

presParty = {'Trump':'R','Obama':'D',"Bush II":'R','Clinton':'D','Bush I':'R','Reagan':'R','Carter':'D','Ford':'R',
           'Nixon':'R', 'Johnson':'D', 'Kennedy':'D', 'Eisenhower':'R'}

# inspired by https://gist.github.com/jlln/338b4b0b55bd6984f883
def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = [admin.strip() for admin in row[target_column].split(separator)]
        number_elem = len(split_row)
        last = split_row[-1:][0]
        for s in split_row:
            admin = s
            new_row = row.to_dict()
            new_row[target_column] = admin
            new_row["approx # years by admin"] = min(adminDur[admin],row["# years DOJ service"]/number_elem)
            new_row["Party when started"] = presParty[last]
            row_accumulator.append(new_row)
        
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    
    new_df = pd.DataFrame(new_rows)
    return new_df

# %%
assert adminDur["Obama"] == 8

# %%
prosecutorsByAdmin = splitDataFrameList(prosecutors,"Admins served under",",")

# %%
prosecutorsByAdmin.astype('object').describe().transpose()
# Out:
#                         count unique                      top  freq
# # years DOJ service      2339     62                        6   130
# Admins served under      2339     12                  Clinton   408
# First name               2339    397                   Robert    91
# Highest DOJ title        2339    495  Assistant U.S. Attorney   201
# Last name                2339    726                  Chapman    21
# Party when started       2339      2                        R  1521
# approx # years by admin  2339     89                        4   483

# %%
prosecutorsByAdmin[0:9]
# Out:
#    # years DOJ service Admins served under First name  \
# 0                 43.0               Obama  Frederick
# 1                 43.0             Bush II  Frederick
# 2                 43.0             Clinton  Frederick
# 3                 43.0              Bush I  Frederick
# 4                 43.0              Reagan  Frederick
# 5                 43.0              Carter  Frederick
# 6                 43.0                Ford  Frederick
# 7                 43.0               Nixon  Frederick
# 8                 43.0             Johnson  Frederick
#
#                                    Highest DOJ title Last name  \
# 0  Director Office of Enforcement Operations, Cri...      Hess
# 1  Director Office of Enforcement Operations, Cri...      Hess
# 2  Director Office of Enforcement Operations, Cri...      Hess
# 3  Director Office of Enforcement Operations, Cri...      Hess
# 4  Director Office of Enforcement Operations, Cri...      Hess
# 5  Director Office of Enforcement Operations, Cri...      Hess
# 6  Director Office of Enforcement Operations, Cri...      Hess
# 7  Director Office of Enforcement Operations, Cri...      Hess
# 8  Director Office of Enforcement Operations, Cri...      Hess
#
#   Party when started  approx # years by admin
# 0                  D                 4.777778
# 1                  D                 4.777778
# 2                  D                 4.777778
# 3                  D                 4.000000
# 4                  D                 4.777778
# 5                  D                 4.000000
# 6                  D                 2.340000
# 7                  D                 4.777778
# 8                  D                 4.777778

# %%
# checking for 12 unique admins
assert len(prosecutorsByAdmin["Admins served under"].unique()) == 12

# %%
pd.value_counts(prosecutorsByAdmin["Party when started"]).plot(kind="bar")

# %%
sns.violinplot(y="Admins served under",x="approx # years by admin",data=prosecutorsByAdmin,estimator=sum)
# every dervice longer than 8 years is suspicous: likely data entry error

# %%
prosecutorsByAdmin[prosecutorsByAdmin["approx # years by admin"]>8]
# Out:
# Empty DataFrame
# Columns: [# years DOJ service, Admins served under, First name, Highest DOJ title, Last name, Party when started, approx # years by admin]
# Index: []

# %%
prosecutorsByAdmin[prosecutorsByAdmin["# years DOJ service"]<0]
# Out:
# Empty DataFrame
# Columns: [# years DOJ service, Admins served under, First name, Highest DOJ title, Last name, Party when started, approx # years by admin]
# Index: []

# %%
ax = sns.barplot(y="Admins served under",x="approx # years by admin",data=prosecutorsByAdmin,estimator=sum)

# %%
prosecutorsByAdmin[prosecutorsByAdmin["Admins served under"]=="Trump"]
# Out:
#       # years DOJ service Admins served under   First name  \
# 9                    42.0               Trump      Burtis
# 17                   41.0               Trump         John
# 52                   38.0               Trump         John
# 92                   37.0               Trump          Ann
# 99                   37.0               Trump          Mel
# 141                  35.0               Trump     Mary Ann
# 169                  34.0               Trump      Deborah
# 187                  34.0               Trump        James
# 193                  34.0               Trump       Burney
# 202                  34.0               Trump       Robert
# 236                  33.0               Trump   Robert Gay
# 279                  33.0               Trump        Peter
# 296                  32.0               Trump        James
# 302                  32.0               Trump      Rodolfo
